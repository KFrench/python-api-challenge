# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint 

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "..\python-api-challenge\Resources\weatherpy\cities1.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to the cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 622

# %%
### Perform API Calls
#Perform a weather check on each city using a series of successive API calls.
#Include a print log of each city as it's being processed (with the city number and city name).

# %%
temp=[]
lat=[]
humi=[]
cloud=[]
wind=[]
for city in cities: 
    base_url= "http://api.openweathermap.org/data/2.5/weather?"
    units="metric"
    city_name=city
    #query_url= base_url + "appid=" + weather_api_key + units + "&q=" + city_name
    query_url = f"{base_url}appid={weather_api_key}&units={units}&q={city_name}"
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()
    try:
        temp.append(weather_json['main']['temp'])
        lat.append(weather_json['coord']['lat'])
        humi.append(weather_json['main']['humidity'])
        cloud.append(weather_json['clouds']['all'])
        wind.append(weather_json['wind']['speed'])
        name= weather_json['name'] 
        id= weather_json['id']
        print(f"The city name is:{name} and the number is: {id}") 
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# The city name is:Bethel and the number is: 5282297
# The city name is:Meulaboh and the number is: 1214488
# Missing field/result... skipping.
# The city name is:Saint Anthony and the number is: 5044290
# The city name is:Ushuaia and the number is: 3833367
# The city name is:Baharly and the number is: 162158
# The city name is:Batagay and the number is: 2027044
# The city name is:Ponta Delgada and the number is: 3372783
# The city name is:Mataura and the number is: 6201424
# The city name is:Ponta do Sol and the number is: 2264557
# The city name is:Alofi and the number is: 4036284
# The city name is:Busselton and the number is: 2075265
# Missing field/result... skipping.
# Missing field/result... skipping.
# The city name is:Olafsvik and the number is: 3414079
# Missing field/result... skipping.
# Missing field/result... skipping.
# The city name is:Sao Joao da Barra and the number is: 3448903
# The city name is:Dalby and the number is: 2169535
# The city name is:Chara and the number is: 2025630
# The city name is:Kiunga and the number is: 2093846
# The city name is:Qaanaaq and the number is: 3831208
# The city name is:Pacific Grove and the number is: 5380437
# The city name is:Kapaa and the number is: 5848280
# The city name is:Castro and the number is: 3466704
# The city name is:Kaminskiy and the number is: 553374
# The city name is:The Valley and the number is: 3573374
# The city name is:Hilo and the number is: 5855927
# The city name is:Saint-Philippe and the number is: 935215
# The city name is:Snaase and the number is: 3138076
# The city name is:Butaritari and the number is: 2110227
# The city name is:Ostrovnoy and the number is: 556268
# The city name is:San Patricio and the number is: 3985168
# The city name is:Chokurdakh and the number is: 2126123
# The city name is:Plettenberg Bay and the number is: 964712
# The city name is:Cherskiy and the number is: 2126199
# The city name is:Albany and the number is: 5106841
# The city name is:Basoko and the number is: 219414
# The city name is:Dzaoudzi and the number is: 921900
# The city name is:Wanning and the number is: 1791779
# The city name is:Sorland and the number is: 3137469
# The city name is:San Quintin and the number is: 3984997
# The city name is:Bambous Virieux and the number is: 1106677
# The city name is:Ilulissat and the number is: 3423146
# The city name is:Bredasdorp and the number is: 1015776
# The city name is:Vila Velha and the number is: 3445026
# The city name is:Ladario and the number is: 3459352
# The city name is:Kaitangata and the number is: 2208248
# Missing field/result... skipping.
# The city name is:Winnipeg and the number is: 6183235
# The city name is:Hermanus and the number is: 3366880
# The city name is:Tiksi and the number is: 2015306
# The city name is:Tommot and the number is: 2015179
# The city name is:Port Elizabeth and the number is: 964420
# The city name is:Rio Gallegos and the number is: 3838859
# The city name is:Udachny and the number is: 2014624
# The city name is:Dagana and the number is: 2246550
# The city name is:Saskylakh and the number is: 2017155
# The city name is:Luderitz and the number is: 3355672
# The city name is:Avarua and the number is: 4035715
# The city name is:Sheksna and the number is: 495062
# The city name is:Pundaguitan and the number is: 1698289
# The city name is:Punta Arenas and the number is: 3874787
# The city name is:Wilmington and the number is: 4499379
# The city name is:Grindavik and the number is: 3416888
# Missing field/result... skipping.
# The city name is:Merauke and the number is: 2082539
# The city name is:Along and the number is: 1278969
# The city name is:Rikitea and the number is: 4030556
# The city name is:Vaini and the number is: 4032243
# The city name is:Vanimo and the number is: 2084442
# The city name is:Yellowknife and the number is: 6185377
# The city name is:Poum and the number is: 2138555
# The city name is:Sampit and the number is: 1628884
# Missing field/result... skipping.
# The city name is:Bereda and the number is: 3105522
# The city name is:Atuona and the number is: 4020109
# The city name is:Novaya Ladoga and the number is: 519630
# The city name is:Kahului and the number is: 5847411
# The city name is:Fayaoue and the number is: 2141305
# The city name is:Port Blair and the number is: 1259385
# The city name is:Puerto Ayora and the number is: 3652764
# The city name is:Gurupa and the number is: 3398480
# The city name is:Airai and the number is: 1651810
# The city name is:New Norfolk and the number is: 2155415
# The city name is:Florianopolis and the number is: 6323121
# The city name is:Manta and the number is: 3654410
# The city name is:Athabasca and the number is: 5887916
# The city name is:Qidong and the number is: 1806840
# The city name is:Oranjestad and the number is: 3577154
# The city name is:Ures and the number is: 3980782
# The city name is:Hobart and the number is: 2163355
# The city name is:Davila and the number is: 1715335
# The city name is:Nanortalik and the number is: 3421765
# The city name is:Verkhnevilyuysk and the number is: 2013639
# The city name is:Guerrero Negro and the number is: 4021858
# The city name is:Adwa and the number is: 344420
# The city name is:Geraldton and the number is: 2070998
# The city name is:Jamestown and the number is: 5122534
# The city name is:Launceston and the number is: 2160517
# The city name is:Price and the number is: 5545269
# The city name is:Sao Filipe and the number is: 3374210
# The city name is:Paamiut and the number is: 3421193
# The city name is:Norman Wells and the number is: 6089245
# The city name is:Huanren and the number is: 2036713
# The city name is:George Town and the number is: 1735106
# The city name is:Mayo and the number is: 4362001
# The city name is:Gimli and the number is: 5961417
# The city name is:Xining and the number is: 1788852
# The city name is:Kudahuvadhoo and the number is: 1337607
# The city name is:Mudanya and the number is: 741487
# The city name is:Paita and the number is: 3694112
# The city name is:Kumba and the number is: 2229752
# The city name is:Khovd and the number is: 1516048
# The city name is:Vardo and the number is: 777019
# The city name is:Belgrade and the number is: 792680
# The city name is:Bouna and the number is: 2290849
# The city name is:San Juan and the number is: 3837213
# The city name is:Salmas and the number is: 117656
# The city name is:Werda and the number is: 932960
# The city name is:Stornoway and the number is: 2636790
# Missing field/result... skipping.
# The city name is:Roald and the number is: 3141667
# The city name is:Moose Factory and the number is: 6078372
# The city name is:Krasnosel'kup and the number is: 1502073
# The city name is:Barrow and the number is: 5880054
# The city name is:Oxapampa and the number is: 3933874
# The city name is:Tuktoyaktuk and the number is: 6170031
# The city name is:Dehui and the number is: 2037712
# The city name is:Dzilam Gonzalez and the number is: 3529654
# The city name is:Nioro and the number is: 2412408
# The city name is:Tasiilaq and the number is: 3424607
# The city name is:Pevek and the number is: 2122090
# The city name is:Tomohon and the number is: 1623446
# The city name is:Qaqortoq and the number is: 3420846
# The city name is:Mahad and the number is: 1264489
# The city name is:Khatanga and the number is: 2022572
# The city name is:Polunochnoye and the number is: 1494482
# The city name is:Soyo and the number is: 2236967
# The city name is:Alice Springs and the number is: 2077895
# The city name is:Thompson and the number is: 6165406
# The city name is:Marsh Harbour and the number is: 3571913
# The city name is:Nikolskoye and the number is: 546105
# The city name is:Naze and the number is: 1855540
# The city name is:Gravdal and the number is: 3155152
# The city name is:Bluff and the number is: 2206939
# The city name is:Tiznit and the number is: 2527087
# The city name is:Hong Kong and the number is: 1819729
# The city name is:Beira and the number is: 1052373
# The city name is:Cape Town and the number is: 3369157
# The city name is:Hithadhoo and the number is: 1282256
# The city name is:Saint George and the number is: 5546220
# The city name is:Oktyabrskoye and the number is: 515805
# The city name is:Cabo San Lucas and the number is: 3985710
# The city name is:Petropavlovsk-Kamchatsky and the number is: 2122104
# The city name is:Kokopo and the number is: 2093685
# The city name is:Karratha and the number is: 6620339
# The city name is:Kavaratti and the number is: 1267390
# The city name is:Kuminskiy and the number is: 1501429
# Missing field/result... skipping.
# The city name is:Mar del Plata and the number is: 3430863
# The city name is:Taltal and the number is: 3870243
# The city name is:Lebu and the number is: 3883457
# Missing field/result... skipping.
# The city name is:Upornaya and the number is: 478920
# The city name is:Sorong and the number is: 1626542
# Missing field/result... skipping.
# The city name is:San Jose and the number is: 5392171
# The city name is:Edd and the number is: 338345
# The city name is:Namatanai and the number is: 2090021
# The city name is:Toamasina and the number is: 1053384
# The city name is:Mount Gambier and the number is: 2156643
# The city name is:Matamoros and the number is: 3996426
# The city name is:La Ronge and the number is: 6050066
# The city name is:Narsaq and the number is: 3421719
# The city name is:Port Alfred and the number is: 964432
# The city name is:Longyearbyen and the number is: 2729907
# The city name is:Kirakira and the number is: 2178753
# The city name is:Biltine and the number is: 244878
# The city name is:Chicama and the number is: 3698359
# The city name is:Nadym and the number is: 1498087
# The city name is:Touros and the number is: 3386213
# The city name is:Phalaborwa and the number is: 965528
# Missing field/result... skipping.
# The city name is:Fortuna and the number is: 5563839
# The city name is:Morehead and the number is: 4301317
# The city name is:Bonavista and the number is: 5905393
# The city name is:Provideniya and the number is: 4031574
# The city name is:Calvinia and the number is: 3369174
# The city name is:Noumea and the number is: 2139521
# Missing field/result... skipping.
# The city name is:Faanui and the number is: 4034551
# The city name is:Ahipara and the number is: 2194098
# The city name is:Wajir and the number is: 178443
# Missing field/result... skipping.
# The city name is:Ribeira Grande and the number is: 3372707
# The city name is:Cacapava do Sul and the number is: 3468560
# The city name is:Saint-Joseph and the number is: 6690296
# The city name is:Quito and the number is: 3652462
# The city name is:Ayan and the number is: 2027316
# The city name is:Tiquisate and the number is: 3591093
# The city name is:East London and the number is: 1006984
# The city name is:Kavieng and the number is: 2094342
# Missing field/result... skipping.
# The city name is:Hailey and the number is: 5594956
# The city name is:Road Town and the number is: 3577430
# The city name is:Margate and the number is: 2643044
# Missing field/result... skipping.
# The city name is:Cine and the number is: 318372
# The city name is:Arraial do Cabo and the number is: 3471451
# Missing field/result... skipping.
# The city name is:Hasaki and the number is: 2112802
# The city name is:Torbay and the number is: 6167817
# The city name is:Skjervoy and the number is: 777682
# The city name is:Los Llanos de Aridane and the number is: 2514651
# The city name is:Prachuap Khiri Khan and the number is: 1151074
# The city name is:Muli and the number is: 1337617
# The city name is:Talnakh and the number is: 1490256
# The city name is:Ucluelet and the number is: 6171633
# The city name is:Kodiak and the number is: 5866583
# Missing field/result... skipping.
# Missing field/result... skipping.
# The city name is:Brae and the number is: 2654970
# The city name is:Nerchinskiy Zavod and the number is: 2019323
# The city name is:Huarmey and the number is: 3939168
# The city name is:Broome and the number is: 5110365
# The city name is:Lugovoy and the number is: 1521293
# The city name is:Vestmannaeyjar and the number is: 3412093
# The city name is:Cidreira and the number is: 3466165
# The city name is:Yangi Marg`ilon and the number is: 1513491
# The city name is:Laas and the number is: 3175096
# The city name is:Arrondissement de Caen and the number is: 3029240
# The city name is:Klaksvik and the number is: 2618795
# The city name is:Brainerd and the number is: 5019116
# The city name is:Olinda and the number is: 3393536
# The city name is:Barka Kana and the number is: 1276927
# The city name is:Kenitra and the number is: 2544571
# Missing field/result... skipping.
# The city name is:Carnarvon and the number is: 2074865
# The city name is:Worland and the number is: 5843495
# Missing field/result... skipping.
# The city name is:Chui and the number is: 3443061
# The city name is:Acarau and the number is: 3408368
# The city name is:Umm Kaddadah and the number is: 364933
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-76193c2888d7> in <module>
#      10     #query_url= base_url + "appid=" + weather_api_key + units + "&q=" + city_name
#      11     query_url = f"{base_url}appid={weather_api_key}&units={units}&q={city_name}"
# ---> 12     weather_response = requests.get(query_url)
#      13     weather_json = weather_response.json()
#      14     try:
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     352             conn.request_chunked(method, url, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#     356         # Reset the timeout for the recv() on the socket
#
# ~\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1242                 encode_chunked=False):
#    1243         """Send a complete request to the server."""
# -> 1244         self._send_request(method, url, body, headers, encode_chunked)
#    1245
#    1246     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1288             # default charset of iso-8859-1.
#    1289             body = _encode(body, 'body')
# -> 1290         self.endheaders(body, encode_chunked=encode_chunked)
#    1291
#    1292     def getresponse(self):
#
# ~\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1237         else:
#    1238             raise CannotSendHeader()
# -> 1239         self._send_output(message_body, encode_chunked=encode_chunked)
#    1240
#    1241     def request(self, method, url, body=None, headers={}, *,
#
# ~\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1024         msg = b"\r\n".join(self._buffer)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#    1028         if message_body is not None:
#
# ~\Anaconda3\lib\http\client.py in send(self, data)
#     964         if self.sock is None:
#     965             if self.auto_open:
# --> 966                 self.connect()
#     967             else:
#     968                 raise NotConnected()
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     179
#     180     def connect(self):
# --> 181         conn = self._new_conn()
#     182         self._prepare_conn(conn)
#     183
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     157         try:
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#     161         except SocketTimeout as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      55     family = allowed_gai_family()
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#      59         sock = None
#
# ~\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     746     # and socket type values to enum constants.
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#     750         addrlist.append((_intenum_converter(af, AddressFamily),
#
# KeyboardInterrupt:

# %%
temp
# Out:
# [286.99,
#  287.26,
#  302.31,
#  303.15,
#  290.72,
#  299.15,
#  300,
#  286.3,
#  249.34,
#  285.93,
#  291.37,
#  300.01,
#  268.58,
#  301.6,
#  267.56,
#  293.15,
#  290.15]

# %%
x_axis=temp
y_axis=lat
plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="blue",
            s=x_axis, alpha=0.25)
plt.show()
# Out:
# C:\Users\test\Anaconda3\lib\site-packages\matplotlib\collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
pprint(weather_json)
# Out:
# {'base': 'model',
#  'clouds': {'all': 86},
#  'cod': 200,
#  'coord': {'lat': 27.13, 'lon': 72.37},
#  'dt': 1579805356,
#  'id': 1259813,
#  'main': {'feels_like': 284.13,
#           'grnd_level': 987,
#           'humidity': 41,
#           'pressure': 1020,
#           'sea_level': 1020,
#           'temp': 288.34,
#           'temp_max': 288.34,
#           'temp_min': 288.34},
#  'name': 'Phalodi',
#  'sys': {'country': 'IN', 'sunrise': 1579831186, 'sunset': 1579869883},
#  'timezone': 19800,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 48, 'speed': 3.63}}

# %%
cities
# Out:
# ['phalodi',
#  'ponta do sol',
#  'butaritari',
#  'touros',
#  'kruisfontein',
#  'vaini',
#  'quatre cocos',
#  'busselton',
#  'fairbanks',
#  'mataura',
#  'redlands',
#  'souillac',
#  'torbay',
#  'kudahuvadhoo',
#  'maniitsoq',
#  'hermanus',
#  'geraldton',
#  'fort saint john',
#  'san-pedro',
#  'yellowknife',
#  'pevek',
#  'sinjah',
#  'hithadhoo',
#  'ion corvin',
#  'severo-kurilsk',
#  'zelenogradskiy',
#  'albany',
#  'rundu',
#  'santiago del estero',
#  'phangnga',
#  'ortigueira',
#  'punta arenas',
#  'carnarvon',
#  'ji-parana',
#  'hilo',
#  'bitung',
#  'hobart',
#  'peringat',
#  'ramhormoz',
#  'kapaa',
#  'esperance',
#  'salalah',
#  'cidreira',
#  'bengkulu',
#  'nanortalik',
#  'pacific grove',
#  'rikitea',
#  'atuona',
#  'miranorte',
#  'bethel',
#  'lorengau',
#  'alta floresta',
#  'east london',
#  'marfino',
#  'coahuayana',
#  'castro',
#  'mys shmidta',
#  'tuktoyaktuk',
#  'mackay',
#  'marawi',
#  'magugu',
#  'amapa',
#  'el balyana',
#  'cacapava do sul',
#  'makakilo city',
#  'lebu',
#  'acarau',
#  'georgetown',
#  'nelson bay',
#  'belmonte',
#  'bredasdorp',
#  'mocambique',
#  'belushya guba',
#  'bluff',
#  'redmond',
#  'vestmannaeyjar',
#  'bathsheba',
#  'san policarpo',
#  'hinesburg',
#  'chuy',
#  'barawe',
#  'novo aripuana',
#  'abbeville',
#  'barcelona',
#  'vyborg',
#  'culasi',
#  'puerto ayora',
#  'cururupu',
#  'flinders',
#  'marystown',
#  'yerbogachen',
#  'attawapiskat',
#  'tsihombe',
#  'qandala',
#  'zutendaal',
#  'barentsburg',
#  'kaka',
#  'merauke',
#  'hunza',
#  'airai',
#  'deputatskiy',
#  'leningradskiy',
#  'mizan teferi',
#  'college',
#  'lahij',
#  'illoqqortoormiut',
#  'port alfred',
#  'grand gaube',
#  'barrow',
#  'kodiak',
#  'hyeres',
#  'thunder bay',
#  'sibolga',
#  'bell ville',
#  'udachnyy',
#  'pedernales',
#  'aripuana',
#  'bouna',
#  'jumla',
#  'richards bay',
#  'taolanaro',
#  'matagami',
#  'yulara',
#  'sao filipe',
#  'hasaki',
#  'yudong',
#  'nikolskoye',
#  'avarua',
#  'arica',
#  'coihaique',
#  'pirgos',
#  'cabo san lucas',
#  'sitka',
#  'matinha',
#  'ushuaia',
#  'vaitupu',
#  'vanimo',
#  'conceicao do araguaia',
#  'saint george',
#  'vao',
#  'emerald',
#  'opunake',
#  'cayenne',
#  'mumford',
#  'labutta',
#  'joshimath',
#  'kindu',
#  'innisfail',
#  'auki',
#  'nizhneyansk',
#  'karratha',
#  'olafsvik',
#  'nome',
#  'khatanga',
#  'haines junction',
#  'zhigansk',
#  'norman wells',
#  'louisbourg',
#  'ribeira grande',
#  'lavrentiya',
#  'port elizabeth',
#  'calderitas',
#  'jamestown',
#  'ginda',
#  'luderitz',
#  'udaipur',
#  'cockburn town',
#  'isangel',
#  'katsuura',
#  'mantua',
#  'oktyabrskoye',
#  'thompson',
#  'dikson',
#  'awassa',
#  'mandali',
#  'kaitangata',
#  'vilhena',
#  'itatinga',
#  'berlevag',
#  'farsund',
#  'labuhan deli',
#  'port blair',
#  'marsh harbour',
#  'liuzhou',
#  'alpena',
#  'sobolevo',
#  'burnie',
#  'bad doberan',
#  'qasigiannguit',
#  'new norfolk',
#  'alofi',
#  'broome',
#  'aklavik',
#  'altay',
#  'moose factory',
#  'clyde river',
#  'jertih',
#  'nichinan',
#  'puerto del rosario',
#  'asau',
#  'angoche',
#  'bathurst',
#  'praia da vitoria',
#  'beyneu',
#  'odweyne',
#  'camocim',
#  'arraial do cabo',
#  'coquimbo',
#  'hobyo',
#  'hambantota',
#  'yanan',
#  'saint-philippe',
#  'dudinka',
#  'rafai',
#  'krasnyye barrikady',
#  'mar del plata',
#  'chalchihuites',
#  'kushikino',
#  'qaanaaq',
#  'tubmanburg',
#  'aswan',
#  'awjilah',
#  'acapulco',
#  'thetford mines',
#  'carutapera',
#  'margate',
#  'saskylakh',
#  'falealupo',
#  'hirara',
#  'taoudenni',
#  'la ronge',
#  'cape town',
#  'oktyabrskiy',
#  'ust-kulom',
#  'nemuro',
#  'gigmoto',
#  'upernavik',
#  'pisco',
#  'namatanai',
#  'ulladulla',
#  'gari',
#  'baie-comeau',
#  'ambilobe',
#  'saint-pierre',
#  'victoria',
#  'jardim',
#  'beringovskiy',
#  'sheregesh',
#  'ribas do rio pardo',
#  'dehloran',
#  'kamaishi',
#  'faanui',
#  'adrar',
#  'katangli',
#  'bucerias',
#  'whittlesea',
#  'tumannyy',
#  'mayor pablo lagerenza',
#  'stepankovice',
#  'seymchan',
#  'blythe',
#  'coruripe',
#  'dzhebariki-khaya',
#  'kamenskoye',
#  'korla',
#  'kavieng',
#  'marv dasht',
#  'hendijan',
#  'sentyabrskiy',
#  'ancud',
#  'cabinda',
#  'chumikan',
#  'cape canaveral',
#  'tigil',
#  'narasannapeta',
#  'teya',
#  'san patricio',
#  'sept-iles',
#  'tiksi',
#  'kisangani',
#  'enshi',
#  'finschhafen',
#  'yanchukan',
#  'port hardy',
#  'wexford',
#  'baranchinskiy',
#  'akhmeta',
#  'chokurdakh',
#  'ust-nera',
#  'malanje',
#  'xam nua',
#  'coracora',
#  'flin flon',
#  'oranjemund',
#  'manoel urbano',
#  'teknaf',
#  'hoquiam',
#  'fortuna',
#  'hamilton',
#  'nuevo casas grandes',
#  'bhadrachalam',
#  'oltu',
#  'kavaratti',
#  'ndioum',
#  'presidencia roque saenz pena',
#  'kendal',
#  'bari',
#  'grenfell',
#  'longyearbyen',
#  'ridgecrest',
#  'tasiilaq',
#  'atambua',
#  'dubai',
#  'astana',
#  'mirnyy',
#  'kainantu',
#  'grindavik',
#  'narsaq',
#  'uwayl',
#  'dioknisi',
#  'umba',
#  'grand river south east',
#  'paamiut',
#  'nuuk',
#  'abu dhabi',
#  'tevaitoa',
#  'jalu',
#  'las cruces',
#  'camopi',
#  'atikokan',
#  'muros',
#  'chhapar',
#  'lompoc',
#  'gazanjyk',
#  'tambo',
#  'vitimskiy',
#  'porbandar',
#  'poronaysk',
#  'ayer itam',
#  'peleduy',
#  'pangkalanbuun',
#  'codrington',
#  'yar',
#  'caravelas',
#  'namtsy',
#  'ilulissat',
#  'barahona',
#  'ca mau',
#  'buin',
#  'bisceglie',
#  'hualmay',
#  'balikpapan',
#  'nantucket',
#  'les cayes',
#  'rio cuarto',
#  'cabano',
#  'amderma',
#  'port hawkesbury',
#  'maceio',
#  'vanavara',
#  'nguru',
#  'wamba',
#  'laguna',
#  'yumen',
#  'barra patuca',
#  'nouakchott',
#  'great falls',
#  'vinukonda',
#  'krasnoselkup',
#  'pierre',
#  'wanning',
#  'vila franca do campo',
#  'iskateley',
#  'bokspits',
#  'khor',
#  'saldanha',
#  'kazalinsk',
#  'iqaluit',
#  'tiznit',
#  'naze',
#  'pushkinskiye gory',
#  'mitsamiouli',
#  'cherskiy',
#  'formosa',
#  'dingle',
#  'beruwala',
#  'namibe',
#  'samusu',
#  'lufilufi',
#  'telenesti',
#  'horta',
#  'jahrom',
#  'the valley',
#  'hami',
#  'cherrapunji',
#  'matamoros',
#  'codajas',
#  'komsomolskiy',
#  'nagato',
#  'havelock',
#  'sarkand',
#  'evansville',
#  'kushmurun',
#  'tongren',
#  'mayumba',
#  'smirnykh',
#  'notre-dame-du-lac',
#  'montlucon',
#  'abapo',
#  'mikuni',
#  'tilichiki',
#  'kalikapur',
#  'sayyan',
#  'gadung',
#  'mende',
#  'shenjiamen',
#  'akyab',
#  'corat',
#  'rochegda',
#  'serdobsk',
#  'kondagaon',
#  'klaksvik',
#  'mahajanga',
#  'lagoa',
#  'antsohihy',
#  'bambous virieux',
#  'phalombe',
#  'roald',
#  'moroto',
#  'pitimbu',
#  'atbasar',
#  'srednekolymsk',
#  'fukuma',
#  'flagstaff',
#  'theunissen',
#  'fort nelson',
#  'marcona',
#  'saurimo',
#  'faya',
#  'tubruq',
#  'provideniya',
#  'halalo',
#  'koungou',
#  'tyup',
#  'avera',
#  'bolshegrivskoye',
#  'la primavera',
#  'qui nhon',
#  'mogochin',
#  'yar-sale',
#  'cao bang',
#  'mahebourg',
#  'marzuq',
#  'sechura',
#  'yarkovo',
#  'meulaboh',
#  'garowe',
#  'ukiah',
#  'aleysk',
#  'ghanzi',
#  'tucupita',
#  'byron bay',
#  'boddam',
#  'topeka',
#  'port lincoln',
#  'makinsk',
#  'corumba',
#  'mount isa',
#  'san clemente',
#  'acajutla',
#  'non sung',
#  'kloulklubed',
#  'dien bien',
#  'nsanje',
#  'tototlan',
#  'rocha',
#  'maningrida',
#  'puyo',
#  'jina',
#  'erzin',
#  'yakeshi',
#  'itarema',
#  'sangmelima',
#  'moree',
#  'ahipara',
#  'san cristobal',
#  'talaya',
#  'palabuhanratu',
#  'scottsburgh',
#  'mahuta',
#  'taft',
#  'ketchikan',
#  'shimoda',
#  'pangnirtung',
#  'wattegama',
#  'santa cruz cabralia',
#  'ngukurr',
#  'kahului',
#  'anzio',
#  'dzaoudzi',
#  'kupang',
#  'zastron',
#  'gboko',
#  'tabou',
#  'fort-shevchenko',
#  'asfi',
#  'loreto',
#  'wasilla',
#  'charleston',
#  'xining',
#  'sabang',
#  'vestmanna',
#  'yanaul',
#  'korem',
#  'cap malheureux',
#  'karagach',
#  'ekhabi',
#  'vallenar',
#  'lima',
#  'alihe',
#  'seddon',
#  'fare',
#  'morros',
#  'gamba',
#  'nhulunbuy',
#  'sorong',
#  'honningsvag',
#  'tecoanapa',
#  'guerrero negro',
#  'uruzgan',
#  'ziarat',
#  'bertoua',
#  'tessalit',
#  'minab',
#  'bandarbeyla',
#  'jeremie',
#  'ballina',
#  'yayva',
#  'tuatapere',
#  'smithers',
#  'irbit',
#  'tromso',
#  'luwuk',
#  'padang',
#  'matai',
#  'leh',
#  'new albany',
#  'westport',
#  'russell',
#  'kankaanpaa',
#  'alugan',
#  'constitucion',
#  'romny',
#  'hirata',
#  'havoysund',
#  'altus',
#  'ecoporanga',
#  'zabol',
#  'sokolo',
#  'garissa',
#  'san jose',
#  'esmeraldas',
#  'yenagoa',
#  'yichang',
#  'kilindoni',
#  'lolua',
#  'launceston',
#  'jiuquan',
#  'villaviciosa',
#  'gombe',
#  'mount gambier',
#  'sommacampagna',
#  'hofn',
#  'henties bay',
#  'inhambane',
#  'killybegs',
#  'wesselsbron',
#  'praia',
#  'pakxe',
#  'elko',
#  'abu samrah',
#  'sedelnikovo',
#  'north bend',
#  'elverum',
#  'zalesovo',
#  'anadyr',
#  'vangaindrano',
#  'lata',
#  'kroya',
#  'yukamenskoye',
#  'lahaina',
#  'tucuman',
#  'gore',
#  'kongoussi',
#  'alakurtti',
#  'pilot butte',
#  'changji',
#  'rawlins',
#  'bongandanga',
#  'lucea',
#  'parkersburg',
#  'sirjan',
#  'nenjiang',
#  'maldonado',
#  'roncade',
#  'waw',
#  'chimbote',
#  'sola',
#  'atar',
#  'lebedinyy',
#  'chino valley',
#  'shahrud',
#  'twin falls',
#  'iquique',
#  'preobrazheniye',
#  'verkhoyansk',
#  'bonavista',
#  'takoradi',
#  'opuwo',
#  'jiddah',
#  'canico',
#  'karasjok',
#  'msanga',
#  'vardo',
#  'baghdad',
#  'santa rosa',
#  'omsukchan',
#  'kalanguy',
#  'japura',
#  'kuala lipis',
#  'muisne',
#  'seshcha',
#  'kalabo',
#  'mucurapo',
#  'juneau',
#  'muscat',
#  'andenes',
#  'shirokiy',
#  'rio grande',
#  'siderno',
#  'benguela',
#  'barbar',
#  'turangi',
#  'aquiraz',
#  'pontes e lacerda',
#  'minsk',
#  'nakama',
#  'damietta']

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
