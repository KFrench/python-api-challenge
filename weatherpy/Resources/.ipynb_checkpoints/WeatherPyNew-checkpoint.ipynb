# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint 

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "..\python-api-challenge\Resources\weatherpy\cities1.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to the cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %%
### Perform API Calls
#Perform a weather check on each city using a series of successive API calls.
#Include a print log of each city as it's being processed (with the city number and city name).

# %%
temp=[]
lat=[]
humi=[]
cloud=[]
wind=[]
long=[]
country=[]
counter = 0
for city in cities: 
    base_url= "http://api.openweathermap.org/data/2.5/weather?"
    units="imperial"
    city_name=city
    #query_url= base_url + "appid=" + weather_api_key + units + "&q=" + city_name
    query_url = f"{base_url}appid={weather_api_key}&units={units}&q={city_name}"
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()
    try:
        temp.append(weather_json['main']['temp'])
        lat.append(weather_json['coord']['lat'])
        long.append(weather_json['coord']['lon'])
        humi.append(weather_json['main']['humidity'])
        cloud.append(weather_json['clouds']['all'])
        wind.append(weather_json['wind']['speed'])
        name= weather_json['name'] 
        country.append(weather_json['sys']['country'])
        counter = counter + 1
        print(f"The city name is:{name} and the number is: {counter}") 
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# The city name is:Hilo and the number is: 1
# Missing field/result... skipping.
# The city name is:New Norfolk and the number is: 2
# The city name is:Acarau and the number is: 3
# The city name is:Stepnyak and the number is: 4
# The city name is:Cape Town and the number is: 5
# The city name is:Rikitea and the number is: 6
# The city name is:Shirokiy and the number is: 7
# The city name is:Luderitz and the number is: 8
# The city name is:Port Elizabeth and the number is: 9
# The city name is:Palekastro and the number is: 10
# The city name is:Road Town and the number is: 11
# The city name is:Las Vegas and the number is: 12
# The city name is:Jamestown and the number is: 13
# The city name is:Bredasdorp and the number is: 14
# The city name is:Qaanaaq and the number is: 15
# The city name is:Kieta and the number is: 16
# The city name is:Puerto Ayora and the number is: 17
# Missing field/result... skipping.
# The city name is:Muhos and the number is: 18
# ...

# %%
cities_pd=pd.DataFrame(cities)

# %%
temp_pd=pd.DataFrame(temp)
lat_pd=pd.DataFrame(lat)
long_pd=pd.DataFrame(long)
humi_pd=pd.DataFrame(humi)
cloud_pd=pd.DataFrame(cloud)
wind_pd=pd.DataFrame(wind)
country_pd=pd.DataFrame(country)

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_all=pd.concat([cities_pd,country_pd,temp_pd,lat_pd,long_pd,humi_pd,cloud_pd,wind_pd],axis=1)
ncolumns=['City', 'Country', 'Temperature(F)', 'Latitude', 'Longitude','Humidity(%)','Cloudiness(%)','Windspeed(mph)']
city_all.columns=ncolumns

# %%
city_all.dropna(axis=0, how="any", inplace=True)
city_all.to_csv("../Resources/citiesall.csv", index=False, header=True)

# %%
cities_csv = "../Resources/citiesall.csv"

# %%
read_file = pd.read_csv(cities_csv)
read_file.head()
# Out:
#           City Country  Temperature(F)  Latitude  Longitude  Humidity(%)  \
# 0         hilo      US           62.11     19.73    -155.09         64.0
# 1    taolanaro      AU           59.07    -42.78     147.06         67.0
# 2  new norfolk      BR           89.82     -2.89     -40.12         54.0
# 3       acarau      KZ           -4.97     52.83      70.78         93.0
# 4     stepnyak      ZA           74.41    -33.93      18.42         53.0
#
#    Cloudiness(%)  Windspeed(mph)
# 0           90.0            8.05
# 1           40.0            9.17
# 2           32.0           11.43
# 3          100.0           17.05
# 4            0.0           14.99

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
x_axis=lat
y_axis=temp
plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="blue",
            s=x_axis, alpha=0.25)
plt.title("City Latitude vs. Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.show()
# Out:
# C:\Users\test\Anaconda3\lib\site-packages\matplotlib\collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
#For the selected cities, the latitude and temperature have a negatively-sloped relationship meaning that as the latitude increases, the temperature decreases.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x_axis=lat
y_axis=humi
plt.scatter(x_axis, y_axis, marker="o", facecolors="red", edgecolors="red",
            s=x_axis, alpha=0.25)
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.show()

# %%
#While there are some outliers, cities having higher latitudes also have higher percent-humidity.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x_axis=lat
y_axis=cloud
plt.scatter(x_axis, y_axis, marker="o", facecolors="black", edgecolors="black",
            s=x_axis, alpha=0.25)
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.show()

# %%
#Based on the graph, the city's latitude and percent-cloudiness do not have a linear relationship. Latitude is not a indicator of the percent cloudiness in the provided data set.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x_axis=lat
y_axis=wind
plt.scatter(x_axis, y_axis, marker="o", facecolors="green", edgecolors="green",
            s=x_axis, alpha=0.25)
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(mph)")
plt.show()

# %%
#Based on the graph, very few of the cities had substantial wind speeds. At the time the call was made to the API, wind speeds for most cities were  moderate, but events such as wind storms, tornadoes, and other major atmospheric changes will impact wind speeds and change the outcome of such graphs.

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
north_pd=read_file[(read_file['Latitude']>=0)]
north_pd
# Out:
#                City Country  Temperature(F)  Latitude  Longitude  Humidity(%)  \
# 0              hilo      US           62.11     19.73    -155.09         64.0
# 3            acarau      KZ           -4.97     52.83      70.78         93.0
# 6           rikitea      RU           -8.16     49.76     129.52         96.0
# 9    port elizabeth      GR           60.01     35.20      26.25         60.0
# 10     palaikastron      VG           80.92     18.42     -64.62         83.0
# ..              ...     ...             ...       ...        ...          ...
# 566   berdigestyakh      GR           60.42     37.07      22.43         51.0
# 567  port macquarie      LY           64.44     29.03      21.55         38.0
# 568            bose      US           39.63     40.77     -72.85         56.0
# 569      coahuayana      QA           64.90     25.29      51.53         68.0
# 571         aljezur      RU          -16.60     61.17      73.17         75.0
#
# ...

# %%
south_pd=read_file[(read_file['Latitude']<0)]
south_pd
# Out:
#             City Country  Temperature(F)  Latitude  Longitude  Humidity(%)  \
# 1      taolanaro      AU           59.07    -42.78     147.06         67.0
# 2    new norfolk      BR           89.82     -2.89     -40.12         54.0
# 4       stepnyak      ZA           74.41    -33.93      18.42         53.0
# 5      cape town      PF           78.98    -23.12    -134.97         80.0
# 7       shirokiy     NaN           65.10    -26.65      15.16         83.0
# ..           ...     ...             ...       ...        ...          ...
# 558          hun      PG           82.09     -5.22     145.80         78.0
# 560       khonuu      AU           76.19    -17.00     145.43         94.0
# 561     bur gabo      EC           76.48     -2.17     -79.90         88.0
# 563  yerbogachen      CL           77.00    -20.22     -70.14         65.0
# 570        pisco      BR           87.01    -22.12     -45.05         53.0
#
#      Cloudiness(%)  Windspeed(mph)
# ...

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
north_pd.dropna()
# Out:
#                City Country  Temperature(F)  Latitude  Longitude  Humidity(%)  \
# 0              hilo      US           62.11     19.73    -155.09         64.0
# 3            acarau      KZ           -4.97     52.83      70.78         93.0
# 6           rikitea      RU           -8.16     49.76     129.52         96.0
# 9    port elizabeth      GR           60.01     35.20      26.25         60.0
# 10     palaikastron      VG           80.92     18.42     -64.62         83.0
# ..              ...     ...             ...       ...        ...          ...
# 566   berdigestyakh      GR           60.42     37.07      22.43         51.0
# 567  port macquarie      LY           64.44     29.03      21.55         38.0
# 568            bose      US           39.63     40.77     -72.85         56.0
# 569      coahuayana      QA           64.90     25.29      51.53         68.0
# 571         aljezur      RU          -16.60     61.17      73.17         75.0
#
# ...

# %%
x_axis=north_pd['Temperature(F)']
y_axis=north_pd['Latitude']

# %%
(slope, intercept,rvalue,pvalue,stderr)=linregress(x_axis,y_axis)
regress_values=x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The r-squared value is {rvalue*rvalue}")
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(15,-30),fontsize=15,color="red")
plt.title("Northern Hemisphere: Max Temp vs. Latitude Linear Regression")
plt.ylabel('Temperature(F)')
plt.xlabel('Latitude')
plt.grid()
plt.savefig('NorthTL.png')

plt.show()
# Out:
# The r-squared value is 0.7926675272261527

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
south_pd.dropna()
# Out:
#             City Country  Temperature(F)  Latitude  Longitude  Humidity(%)  \
# 1      taolanaro      AU           59.07    -42.78     147.06         67.0
# 2    new norfolk      BR           89.82     -2.89     -40.12         54.0
# 4       stepnyak      ZA           74.41    -33.93      18.42         53.0
# 5      cape town      PF           78.98    -23.12    -134.97         80.0
# 8       luderitz      ZA           75.20    -33.92      25.57         44.0
# ..           ...     ...             ...       ...        ...          ...
# 558          hun      PG           82.09     -5.22     145.80         78.0
# 560       khonuu      AU           76.19    -17.00     145.43         94.0
# 561     bur gabo      EC           76.48     -2.17     -79.90         88.0
# 563  yerbogachen      CL           77.00    -20.22     -70.14         65.0
# 570        pisco      BR           87.01    -22.12     -45.05         53.0
#
#      Cloudiness(%)  Windspeed(mph)
# ...

# %%
x_axis=south_pd['Temperature(F)']
y_axis=south_pd['Latitude']

# %%
(slope, intercept,rvalue,pvalue,stderr)=linregress(x_axis,y_axis)
regress_values=x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The r-squared value is {rvalue*rvalue}")
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(15,-30),fontsize=15,color="red")
plt.title("Southern Hemisphere: Max Temp vs. Latitude Linear Regression")
plt.ylabel('Temperature(F)')
plt.xlabel('Latitude')
plt.grid()
plt.savefig('SouthTL.png')
plt.show()
# Out:
# The r-squared value is 0.24871274306429422

# %%
#Max Temp vs Latitude: This model is used to determine the strenght of effect that the latitude, the independent variable, has on the city's maximum temperature. In the northern hemisphere, higher latitudes lower the temperatude. In the southern hemisphere, higher latitudes increase the temperature. This supports the fairly well-known fact that the closer you are to the equator, the warmer it is.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_axis=north_pd['Latitude']
y_axis=north_pd['Humidity(%)']

# %%
(slope, intercept,rvalue,pvalue,stderr)=linregress(x_axis,y_axis)
regress_values=x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The r-squared value is {rvalue*rvalue}")
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title("Northern Hemisphere: Latitude vs. Humidity Linear Regression")
plt.ylabel('Humidity')
plt.xlabel('Latitude')
plt.grid()
plt.savefig('NorthHL.png')
plt.show()
# Out:
# The r-squared value is 0.20446021022062938

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_axis=south_pd['Latitude']
y_axis=south_pd['Humidity(%)']

# %%
(slope, intercept,rvalue,pvalue,stderr)=linregress(x_axis,y_axis)
regress_values=x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The r-squared value is {rvalue*rvalue}")
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(15,-30),fontsize=15,color="red")
plt.title("Southern Hemisphere:Latitude vs. Humidity(%) Linear Regression")
plt.ylabel('Humidity(%)')
plt.xlabel('Latitude')
plt.grid()
plt.savefig('SouthHL.png')
plt.show()
# Out:
# The r-squared value is 0.03422760978394868

# %%
#Humidity vs Latitude: The linear regression is modeling a stronger relationship between the humidity and latitude in the northern hemisphere (data is closer to line of best fit) and a weaker relationship in the southern hemisphere (lots of spread from line of best fit).

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_axis=north_pd['Latitude']
y_axis=north_pd['Cloudiness(%)']

# %%
(slope, intercept,rvalue,pvalue,stderr)=linregress(x_axis,y_axis)
regress_values=x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The r-squared value is {rvalue*rvalue}")
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(6,-50),fontsize=15,color="red")
plt.title("Northern Hemisphere: Latitude vs. Cloudiness(%) Linear Regression")
plt.ylabel('Cloudiness(%)')
plt.xlabel('Latitude')
plt.grid()
plt.savefig('NorthCL.png')
plt.show()
# Out:
# The r-squared value is 0.11796631233459158

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_axis=south_pd['Latitude']
y_axis=south_pd['Cloudiness(%)']

# %%
(slope, intercept,rvalue,pvalue,stderr)=linregress(x_axis,y_axis)
regress_values=x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The r-squared value is {rvalue*rvalue}")
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(15,-40),fontsize=15,color="red")
plt.title("Southern Hemisphere: Latitude vs. Cloudiness(%) Linear Regression")
plt.ylabel('Cloudiness(%)')
plt.xlabel('Latitude')
plt.grid()
plt.savefig('SouthCL.png')
plt.show()
# Out:
# The r-squared value is 0.06676938088695979

# %%
#Cloudiness vs Latitude: In both the northern and southern hemispeheres, the data shows nearly no relationship between latitude and percent cloudiness in the selected cities.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_axis=north_pd['Latitude']
y_axis=north_pd['Windspeed(mph)']

# %%
(slope, intercept,rvalue,pvalue,stderr)=linregress(x_axis,y_axis)
regress_values=x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The r-squared value is {rvalue*rvalue}")
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title("Northern Hemisphere: Latitude vs. Windspeed(mph) Linear Regression")
plt.ylabel('Windspeed(mph)')
plt.xlabel('Latitude')
plt.grid()
plt.savefig('NorthWL.png')
plt.show()
# Out:
# The r-squared value is 0.0047855567066338615

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_axis=south_pd['Latitude']
y_axis=south_pd['Windspeed(mph)']

# %%
(slope, intercept,rvalue,pvalue,stderr)=linregress(x_axis,y_axis)
regress_values=x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The r-squared value is {rvalue*rvalue}")
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(15,-40),fontsize=15,color="red")
plt.title("Southern Hemisphere: Latitude vs. Windspeed(mph) Linear Regression")
plt.ylabel('Windspeed(mph)')
plt.xlabel('Latitude')
plt.grid()
plt.savefig('SouthWL.png')
plt.show()
# Out:
# The r-squared value is 0.17364446019539195

# %%
#Wind Speed vs Latitude: Based on the graph,there is not a strong correlation between latitude and wind speeds. At the time the call was made to the API, wind speeds for most cities were  moderate, but events such as wind storms, tornadoes, and other major atmospheric changes will impact wind speeds and change the outcome of such graphs.
